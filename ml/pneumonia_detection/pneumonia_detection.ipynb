# %%
! pip install clearml roboflow rich ultralytics onnxruntime  python-dotenv certifi
# Out:
# Collecting clearml
#   Downloading clearml-2.1.5-py2.py3-none-any.whl.metadata (18 kB)
# Collecting roboflow
#   Downloading roboflow-1.3.7-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (13.9.4)
# Collecting ultralytics
#   Downloading ultralytics-8.4.45-py3-none-any.whl.metadata (39 kB)
# Collecting onnxruntime
#   Downloading onnxruntime-1.25.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (2026.4.22)
# Requirement already satisfied: attrs>=18.0 in /usr/local/lib/python3.12/dist-packages (from clearml) (26.1.0)
# Collecting furl>=2.0.0 (from clearml)
#   Downloading furl-2.1.4-py2.py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: jsonschema>=2.6.0 in /usr/local/lib/python3.12/dist-packages (from clearml) (4.26.0)
# Collecting pathlib2>=2.3.0 (from clearml)
#   Downloading pathlib2-2.3.7.post1-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: psutil>=3.4.2 in /usr/local/lib/python3.12/dist-packages (from clearml) (5.9.5)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from clearml) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.12/dist-packages (from clearml) (2.9.0.post0)
# Requirement already satisfied: pyjwt<3.0.0,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from clearml) (2.12.1)
# Requirement already satisfied: PyYAML>=3.12 in /usr/local/lib/python3.12/dist-packages (from clearml) (6.0.3)
# Requirement already satisfied: six>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from clearml) (1.17.0)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from clearml) (2.5.0)
# Requirement already satisfied: Pillow>=10.3.0 in /usr/local/lib/python3.12/dist-packages (from clearml) (11.3.0)
# Requirement already satisfied: referencing<0.40 in /usr/local/lib/python3.12/dist-packages (from clearml) (0.37.0)
# Requirement already satisfied: requests>=2.32.0 in /usr/local/lib/python3.12/dist-packages (from clearml) (2.32.4)
# Requirement already satisfied: numpy>=1.26.4 in /usr/local/lib/python3.12/dist-packages (from clearml) (2.0.2)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.12/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.5.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from roboflow) (3.10.0)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting pi-heif<2 (from roboflow)
#   Downloading pi_heif-1.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.3 kB)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.5.5-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (2.2 kB)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.67.3)
# Requirement already satisfied: requests_toolbelt in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.0.0)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: typer>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (0.24.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich) (2.20.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.10.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.25.0+cu128)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.19-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (25.12.19)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (26.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (5.29.6)
# Collecting orderedmultidict>=1.0.1 (from furl>=2.0.0->clearml)
#   Downloading orderedmultidict-1.0.2-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6.0->clearml) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6.0->clearml) (0.30.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (4.62.1)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from referencing<0.40->clearml) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.0->clearml) (3.4.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.29.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.8.0->ultralytics) (1.5.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer>=0.12.0->roboflow) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.12.0->roboflow) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.12.0->roboflow) (0.0.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading clearml-2.1.5-py2.py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 77.9 MB/s eta 0:00:00
# Downloading roboflow-1.3.7-py3-none-any.whl (195 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.8/195.8 kB 25.2 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 8.7 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.7 MB/s eta 0:00:00
# Downloading ultralytics-8.4.45-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 78.5 MB/s eta 0:00:00
# Downloading onnxruntime-1.25.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 99.0 MB/s eta 0:00:00
# Downloading furl-2.1.4-py2.py3-none-any.whl (27 kB)
# Downloading pathlib2-2.3.7.post1-py2.py3-none-any.whl (18 kB)
# Downloading pi_heif-1.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 82.9 MB/s eta 0:00:00
# Downloading pillow_avif_plugin-1.5.5-cp312-cp312-manylinux_2_28_x86_64.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 136.0 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.19-py3-none-any.whl (28 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading orderedmultidict-1.0.2-py2.py3-none-any.whl (11 kB)
# Installing collected packages: pillow-avif-plugin, filetype, pi-heif, pathlib2, orderedmultidict, opencv-python-headless, onnxruntime, idna, furl, ultralytics-thop, roboflow, clearml, ultralytics
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.13
#     Uninstalling idna-3.13:
#       Successfully uninstalled idna-3.13
# Successfully installed clearml-2.1.5 filetype-1.2.0 furl-2.1.4 idna-3.7 onnxruntime-1.25.1 opencv-python-headless-4.10.0.84 orderedmultidict-1.0.2 pathlib2-2.3.7.post1 pi-heif-1.3.0 pillow-avif-plugin-1.5.5 roboflow-1.3.7 ultralytics-8.4.45 ultralytics-thop-2.0.19

# %%
"""
ClearML helpers shared across all training scripts.
Reads credentials from environment / ~/.clearml.conf.
"""

import os
from typing import Any

from clearml import Dataset, Task
from dotenv import load_dotenv

load_dotenv("env")


def init_task(
    project: str,
    name: str,
    task_type: Task.TaskTypes = Task.TaskTypes.training,
    tags: list[str] | None = None,
    config: dict[str, Any] | None = None,
    reuse_last_task_id: bool = False,
) -> Task:
    """
    Initialise a ClearML task and connect hyperparameters.

    Args:
        project:  ClearML project name, e.g. "MedVision/MRI-Segmentation"
        name:     Task name, e.g. "train-yolo-v1"
        task_type: training | testing | inference | ...
        tags:     Optional list of tags shown in the UI
        config:   Dict of hyperparameters to log (auto-connected)
        reuse_last_task_id: Set True only in interactive/notebook sessions

    Returns:
        Initialised ClearML Task
    """
    task = Task.init(
        project_name=project,
        task_name=name,
        task_type=task_type,
        tags=tags or [],
        reuse_last_task_id=reuse_last_task_id,
        auto_connect_frameworks={
            "pytorch": True,
            "tensorboard": False,
            "matplotlib": True,
        },
    )

    if config:
        task.connect(config, name="Hyperparameters")

    return task


def get_or_create_dataset(
    dataset_name: str,
    project: str,
    local_path: str,
    tags: list[str] | None = None,
) -> Dataset:
    """
    Upload a local dataset folder to ClearML if it doesn't exist yet.
    Returns the Dataset object (use .get_local_copy() to get the local path).
    """
    try:
        dataset = Dataset.get(
            dataset_name=dataset_name,
            dataset_project=project,
            auto_create=False,
        )
        print(f"[ClearML] Dataset '{dataset_name}' already exists — reusing.")
        return dataset
    except Exception:
        pass

    print(f"[ClearML] Creating dataset '{dataset_name}' from {local_path} ...")
    dataset = Dataset.create(
        dataset_name=dataset_name,
        dataset_project=project,
        dataset_tags=tags or [],
    )
    dataset.add_local_files(str(local_path))
    dataset.upload()
    dataset.finalize()
    print(f"[ClearML] Dataset uploaded — ID: {dataset.id}")
    return dataset


def log_metrics(task: Task, metrics: dict[str, float], epoch: int) -> None:
    """Log a dict of scalar metrics for the current epoch."""
    logger = task.get_logger()
    for name, value in metrics.items():
        series, title = (name.split("/", 1) + [name])[:2]
        logger.report_scalar(title=title, series=series, value=value, iteration=epoch)


def upload_model(task: Task, model_path: str, name: str) -> None:
    """Upload a model file as a Task artifact."""
    task.upload_artifact(name=name, artifact_object=str(model_path))
    print(f"[ClearML] Model '{name}' uploaded from {model_path}")

# %%
import os
import sys
import argparse
from pathlib import Path
import certifi

os.environ["SSL_CERT_FILE"] = certifi.where()
os.environ["REQUESTS_CA_BUNDLE"] = certifi.where()

from roboflow import Roboflow

DATA_ROOT = Path("data")
API_KEY = os.getenv("ROBOFLOW_API_KEY", "")

DATASETS = {
    "mri": (
        "classification-brain-tumor-teqsl",
        "brain-tumor-segmentation-r4in2",
        2,
        "mri_segmentation",
    ),
    "pneumonia": (
        "siim-cxr",
        "pneumonia-detection-ssibx",
        3,
        "pneumonia_detection",
    ),
    "skin": (
        "skin-nbezt",
        "skin-lesion-jxjgm",
        8,
        "skin_classification",
    ),
}

FORMAT = "yolov11"

def count_images(path: Path) -> int:
    return sum(1 for _ in path.rglob("*") if _.suffix.lower() in {".jpg", ".jpeg", ".png"})

def download(task: str):
    workspace, project_slug, version_num, folder = DATASETS[task]
    dest = DATA_ROOT / folder

    print(f"\n--- {task.upper()} ---")
    print(f"Connecting to: {workspace}/{project_slug} (v{version_num})")

    rf = Roboflow(api_key=API_KEY)
    project = rf.workspace(workspace).project(project_slug)
    version = project.version(version_num)

    print(f"Downloading to: {dest}")
    version.download(FORMAT, location=str(dest), overwrite=True)

    n = count_images(dest)
    print(f"Done — {n:,} images")

def create_dataset_main(task_arg="all"):
    if not API_KEY or API_KEY == "ВАШ_API_KEY_ИЛИ_ПЕРЕМЕННАЯ":
        print("Ошибка: Укажите свой ROBOFLOW_API_KEY")
        return

    targets = list(DATASETS.keys()) if task_arg == "all" else [task_arg]

    print(f"Targets: {', '.join(targets)}")

    for task in targets:
        download(task)

    print("\n=== SUMMARY ===")
    for task in targets:
        _, _, _, folder = DATASETS[task]
        dest = DATA_ROOT / folder
        splits = {s: count_images(dest / s) for s in ("train", "valid", "test") if (dest / s).exists()}
        split_str = "  ".join(f"{k}: {v:,}" for k, v in splits.items())
        print(f"{task:<12} {split_str}")


create_dataset_main("pneumonia")
# Out:
# Targets: pneumonia
#
# --- PNEUMONIA ---
# Connecting to: siim-cxr/pneumonia-detection-ssibx (v3)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading to: data/pneumonia_detection
# Downloading Dataset Version Zip in data/pneumonia_detection to yolov11:: 100%|██████████| 50863/50863 [00:04<00:00, 10527.64it/s]
# Extracting Dataset Version Zip to data/pneumonia_detection in yolov11:: 100%|██████████| 37195/37195 [00:03<00:00, 12282.94it/s]
# Done — 18,595 images
#
# === SUMMARY ===
# pneumonia    train: 16,749  valid: 739  test: 1,107

# %%
import sys
from pathlib import Path
import yaml
from ultralytics import YOLO

DATA_YAML = Path("data") / "pneumonia_detection" / "data.yaml"
CONFIG_FILE = Path("config.yaml")

def train_mri() -> None:
    if not CONFIG_FILE.exists():
        print(f"Ошибка: Файл {CONFIG_FILE} не найден!")
        return

    cfg = yaml.safe_load(CONFIG_FILE.read_text())

    no_clearml = cfg.get("no_clearml", False)

    if not no_clearml:
        task = init_task(
            project=cfg["clearml_project"],
            name=cfg["clearml_task"],
            tags=["yolo26", "pneumonia", "detection"],
            config=cfg,
        )

    model_path = cfg.get("resume") if cfg.get("resume") else cfg["model"]
    model = YOLO(model_path)

    results = model.train(
        data=str(DATA_YAML),
        task="detect",
        epochs=cfg["epochs"],
        imgsz=cfg["imgsz"],
        batch=cfg["batch"],
        lr0=cfg["lr0"],
        lrf=cfg["lrf"],
        momentum=cfg["momentum"],
        weight_decay=cfg["weight_decay"],
        warmup_epochs=cfg["warmup_epochs"],
        patience=cfg["patience"],
        dropout=cfg["dropout"],
        hsv_h=cfg["hsv_h"],
        hsv_s=cfg["hsv_s"],
        hsv_v=cfg["hsv_v"],
        degrees=cfg["degrees"],
        translate=cfg["translate"],
        scale=cfg["scale"],
        flipud=cfg["flipud"],
        fliplr=cfg["fliplr"],
        mosaic=cfg["mosaic"],
        project=str(cfg["project"]),
        name=cfg["name"],
        save=True,
        save_period=cfg["save_period"],
        resume=bool(cfg.get("resume")),
        device=0,
        plots=True,
        verbose=True,
    )

    best = Path(results.save_dir) / "weights" / "best.pt"
    print(f"\nBest model: {best}")

    if not no_clearml:
        upload_model(task, best, "pneumonia-detection-best")
        task.close()

train_mri()
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ClearML Task: created new task id=e8864f4f19434697b56ae86781787840
# invalid escape sequence '\/'
# ClearML results page: https://app.clear.ml/projects/c336f4f6bfc04cd1baddee81aa644572/experiments/e8864f4f19434697b56ae86781787840/output/log
# WARNING:root:Unsupported key of type '<class 'int'>' found when connecting dictionary. It will be converted to str
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 196.7MB/s 0.0s
# Ultralytics 8.4.45 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data/pneumonia_detection/data.yaml, degrees=5.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=60, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/pneumonia_detection, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/runs/pneumonia_detection/train, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 130.2MB/s 0.0s
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    242346  ultralytics.nn.modules.head.Detect           [3, 1, True, [64, 128, 256]]
# YOLO26n summary: 260 layers, 2,504,970 parameters, 2,504,970 gradients, 5.8 GFLOPs
#
# Transferred 606/708 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 109.8±85.2 MB/s, size: 2.8 KB)
# train: Scanning /content/data/pneumonia_detection/train/labels... 16736 images, 0 backgrounds, 13 corrupt: 100% ━━━━━━━━━━━━ 16749/16749 2.0Kit/s 8.4s
# train: /content/data/pneumonia_detection/train/images/4f11b62bab24_image_png.rf.8321e5735ac691d3fb22d2dea8aab9b6.jpg: ignoring corrupt image/label: image size (13, 8) <10 pixels
# train: /content/data/pneumonia_detection/train/images/6373fdd11ed0_image_png.rf.a428283f34ab371b69120b7aea0a99bc.jpg: ignoring corrupt image/label: image size (9, 24) <10 pixels
# train: /content/data/pneumonia_detection/train/images/78108839e24b_image_png.rf.362d9c3b4c9b9b60f9079416c3d976d8.jpg: ignoring corrupt image/label: image size (53, 3) <10 pixels
# train: /content/data/pneumonia_detection/train/images/78108839e24b_image_png.rf.da6adb8fdf67384b12c1e3467e100f06.jpg: ignoring corrupt image/label: image size (52, 9) <10 pixels
# train: /content/data/pneumonia_detection/train/images/af1a0e5a5b49_image_png.rf.4e6ad929467e846f0874ea8ddf4635fd.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# train: /content/data/pneumonia_detection/train/images/af1a0e5a5b49_image_png.rf.907fcb7363db87cc2b30da4961d6d95d.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# train: /content/data/pneumonia_detection/train/images/af1a0e5a5b49_image_png.rf.c9ec7a1bfe3764cd82852bc6fde59214.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# train: /content/data/pneumonia_detection/train/images/b570de3efeed_image_png.rf.7f5aa28637581a6b6d123969e6466bd4.jpg: ignoring corrupt image/label: image size (9, 16) <10 pixels
# train: /content/data/pneumonia_detection/train/images/b570de3efeed_image_png.rf.9543f713897c0cf908bc0a8787411f3b.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: /content/data/pneumonia_detection/train/images/b570de3efeed_image_png.rf.a15e2c5da125de631d79b1e859645c0c.jpg: ignoring corrupt image/label: image size (7, 16) <10 pixels
# train: /content/data/pneumonia_detection/train/images/b570de3efeed_image_png.rf.be10f9dbefc872841d23dd37695d8142.jpg: ignoring corrupt image/label: image size (14, 8) <10 pixels
# train: /content/data/pneumonia_detection/train/images/b570de3efeed_image_png.rf.e0164173e96bac106f2271afb1ed324e.jpg: ignoring corrupt image/label: image size (8, 16) <10 pixels
# train: /content/data/pneumonia_detection/train/images/b570de3efeed_image_png.rf.eb4cea270db11c608af2a419a19d575b.jpg: ignoring corrupt image/label: image size (14, 9) <10 pixels
# train: New cache created: /content/data/pneumonia_detection/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 27.1±18.2 MB/s, size: 1.1 KB)
# val: Scanning /content/data/pneumonia_detection/valid/labels... 739 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 739/739 893.8it/s 0.8s
# val: New cache created: /content/data/pneumonia_detection/valid/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.01, momentum=0.9) with parameter groups 114 weight(decay=0.0), 126 weight(decay=0.0005), 126 bias(decay=0.0)
# Plotting labels to /content/runs/detect/runs/pneumonia_detection/train/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/runs/pneumonia_detection/train
# Starting training for 60 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/60      4.71G       0.59      4.598    0.01634        109        640: 29% ━━━╸──────── 154/523 1.2it/s 2:26<5:05ClearML Monitor: Could not detect iteration reporting, falling back to iterations as seconds-from-start
#        1/60      4.71G     0.4188      2.741    0.01121        105        640: 100% ━━━━━━━━━━━━ 523/523 1.1it/s 7:48
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.4s/it 40.3s
#                    all        739        739       0.31      0.613      0.398      0.379
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/60      5.54G     0.3597     0.8982   0.009167        104        640: 100% ━━━━━━━━━━━━ 523/523 1.2it/s 6:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.2it/s 3.8s
#                    all        739        739      0.318      0.607       0.41      0.396
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/60      5.54G     0.4103      0.774    0.01029        108        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.1it/s 3.9s
#                    all        739        739      0.322      0.708      0.388      0.361
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/60      5.54G     0.4047     0.7352   0.009993        105        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.6it/s 4.6s
#                    all        739        739      0.361      0.643      0.431      0.402
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/60      5.54G     0.3514     0.7081   0.008492         96        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.8it/s 4.2s
#                    all        739        739      0.332      0.793      0.426      0.396
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/60      5.54G     0.3235     0.6992   0.007722        104        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:16
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.2it/s 3.7s
#                    all        739        739      0.266       0.64      0.395       0.37
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/60      5.54G     0.2963     0.6899    0.00708        109        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:15
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.1it/s 5.7s
#                    all        739        739      0.339      0.738      0.433      0.404
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/60      5.54G     0.2772     0.6787   0.006527        105        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.7it/s 4.4s
#                    all        739        739       0.32      0.754      0.411       0.38
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/60      5.54G     0.2603     0.6711   0.006181        113        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.3it/s 3.7s
#                    all        739        739      0.342      0.864      0.467      0.461
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/60      5.54G     0.2509     0.6676   0.005938        107        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.9it/s 4.1s
#                    all        739        739      0.305      0.761      0.394      0.386
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/60      5.55G     0.2446     0.6615   0.005775         91        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.5it/s 4.9s
#                    all        739        739      0.322        0.8      0.449      0.438
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/60      5.55G     0.2322     0.6552   0.005472        109        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:16
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.1it/s 3.8s
#                    all        739        739      0.268      0.765      0.443      0.428
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/60      5.55G     0.2273     0.6562   0.005341        103        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.9it/s 4.2s
#                    all        739        739      0.374      0.691      0.478      0.472
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/60      5.55G     0.2171     0.6538   0.005058         98        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.8it/s 4.2s
#                    all        739        739      0.383      0.727      0.464      0.458
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/60      5.55G     0.2182     0.6529   0.005063        113        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.5it/s 4.9s
#                    all        739        739      0.368      0.662      0.462      0.454
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/60      5.55G     0.2117     0.6499   0.004901        112        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.2it/s 3.7s
#                    all        739        739      0.312      0.851      0.431      0.423
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/60      5.55G     0.2062     0.6486   0.004757        105        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.9it/s 4.1s
#                    all        739        739      0.296      0.749      0.399      0.392
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/60      5.55G     0.2018     0.6456   0.004651        102        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.1it/s 3.9s
#                    all        739        739      0.398      0.676      0.485      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/60      5.55G     0.1951     0.6419   0.004486        104        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.5it/s 4.7s
#                    all        739        739       0.39      0.732      0.466       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/60      5.55G     0.1954     0.6454   0.004466         98        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.2it/s 3.7s
#                    all        739        739      0.363      0.682       0.47      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/60      5.55G      0.192     0.6396   0.004438        112        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.2it/s 3.7s
#                    all        739        739      0.383       0.67      0.509      0.496
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/60      5.55G     0.1909     0.6406   0.004401        106        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.9it/s 4.1s
#                    all        739        739      0.375      0.701      0.486      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/60      5.55G     0.1877     0.6358   0.004249        106        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.9it/s 4.1s
#                    all        739        739      0.378      0.773      0.481      0.477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/60      5.55G     0.1816     0.6379   0.004148        112        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.5it/s 4.8s
#                    all        739        739      0.419      0.647      0.487      0.476
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/60      5.55G     0.1824     0.6386    0.00415        104        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.4it/s 5.1s
#                    all        739        739      0.438      0.586      0.492       0.49
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/60      5.55G     0.1806     0.6316   0.004093         97        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.7it/s 4.4s
#                    all        739        739      0.467      0.617      0.516      0.512
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/60      5.55G     0.1756     0.6369   0.003979         97        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.2it/s 3.7s
#                    all        739        739      0.461      0.569      0.515      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/60      5.55G     0.1758     0.6334   0.003999         99        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.3it/s 5.1s
#                    all        739        739       0.41      0.617      0.509      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/60      5.55G     0.1698     0.6314   0.003842        102        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.2it/s 3.7s
#                    all        739        739      0.494      0.574      0.519      0.512
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/60      5.55G     0.1678     0.6261   0.003811        101        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:17
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.5it/s 4.9s
#                    all        739        739      0.411      0.725       0.51      0.507
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/60      5.55G     0.1651     0.6309    0.00374        109        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.3it/s 3.6s
#                    all        739        739      0.393      0.805      0.513      0.509
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/60      5.55G     0.1606     0.6253   0.003591        108        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.5it/s 4.9s
#                    all        739        739      0.414      0.657       0.53      0.529
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/60      5.55G     0.1611     0.6299   0.003653        109        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.2it/s 3.8s
#                    all        739        739      0.487      0.567      0.507      0.503
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/60      5.55G      0.159     0.6204   0.003609        100        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.5it/s 4.9s
#                    all        739        739      0.477       0.64      0.541      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/60      5.55G     0.1524     0.6188   0.003443         99        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:16
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.2it/s 3.7s
#                    all        739        739      0.489      0.599      0.538      0.536
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/60      5.55G     0.1479     0.6193   0.003332         97        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.5it/s 4.7s
#                    all        739        739      0.447      0.599      0.533      0.532
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/60      5.55G      0.141     0.6145    0.00319         94        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.2it/s 3.7s
#                    all        739        739      0.474       0.59      0.532      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/60      5.55G      0.139     0.6118   0.003139        115        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.8it/s 4.3s
#                    all        739        739      0.453      0.662      0.525      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/60      5.55G     0.1371     0.6079   0.003064        105        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.9it/s 4.2s
#                    all        739        739      0.424      0.642      0.523      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/60      5.55G     0.1337     0.6072   0.003009        105        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.2it/s 3.8s
#                    all        739        739      0.426      0.645      0.518      0.517
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/60      5.55G     0.1281     0.6066   0.002864         98        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.2it/s 3.7s
#                    all        739        739       0.44      0.649      0.526      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/60      5.55G     0.1255      0.602   0.002841        109        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.2it/s 3.7s
#                    all        739        739       0.45      0.621      0.527      0.526
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/60      5.55G     0.1202     0.5998   0.002678        110        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.2it/s 5.6s
#                    all        739        739      0.449      0.621      0.526      0.526
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/60      5.55G     0.1166     0.6007   0.002579        105        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.9it/s 4.2s
#                    all        739        739      0.454      0.629       0.53       0.53
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/60      5.55G     0.1092     0.5954   0.002434        103        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.8it/s 4.3s
#                    all        739        739      0.447      0.663      0.526      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/60      5.55G     0.1071     0.5955   0.002366        109        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.4it/s 5.1s
#                    all        739        739      0.442      0.659      0.522      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/60      5.55G     0.1023     0.5904   0.002289         96        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.2it/s 3.8s
#                    all        739        739      0.441      0.641      0.529      0.529
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/60      5.55G    0.09805     0.5849   0.002168        102        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.0it/s 4.0s
#                    all        739        739       0.44      0.661      0.528      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/60      5.55G    0.09496     0.5831   0.002126         92        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.6it/s 4.7s
#                    all        739        739      0.444      0.707      0.523      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/60      5.55G    0.09266     0.5826   0.002059         91        640: 100% ━━━━━━━━━━━━ 523/523 1.4it/s 6:15
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.7it/s 4.5s
#                    all        739        739      0.449      0.649      0.528      0.528
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/60      5.55G     0.1007     0.5762   0.004139         32        640: 30% ━━━╸──────── 157/523 1.2it/s 2:01<5:12
